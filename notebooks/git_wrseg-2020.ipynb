# %%
# WRSeg 2020 - https://github.com/alexcamargoweb/wrseg-2020
# Repositório do minicurso: Fake News - Conceitos, métodos e aplicações de identificação e mitigação.
# Notebook de configuração e execução do git via Colab/GitHub
# Arquivo: git_wrseg-2020.ipynb

# %%
# CONFIGURAÇÕES INICIAIS DE SSH PARA REPOSITÓRIOS PRIVADOS DO GITHUB 
# Lembrando: esses comandos funcionarão no seu próprio repositório
# Importante: Executar um comando de cada vez

# Carrega os dados do Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Limpa as saídas do terminal
output.clear()

# Gera uma chave
# !ssh-keygen -t rsa -b 4096 -C "alexcamargoweb@gmail.com"

# Adicione a saída do comando abaixo no seu perfil do GitHub
# !cat /root/.ssh/id_rsa.pub

# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# !chmod 600 /root/.ssh/id_rsa

# !ssh -T git@github.com

# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"

# %cd /content/drive/MyDrive/
# %ls /content/drive/MyDrive/

# !git clone git@github.com:alexcamargoweb/wrseg-2020.git

# %cd wrseg-2020/
# %ls /content/drive/MyDrive/wrseg-2020/

# %%
# CONFIGURAÇÕES FUTURAS DE SSH PARA REPOSITÓRIOS PRIVADOS DO GITHUB (APÓS O PRIMEIRO ACESSO)
key = \
'''
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
'''
# !mkdir -p /root/.ssh
with open(r'/root/.ssh/id_rsa', 'w', encoding = 'utf8') as fh:
    fh.write(key)
# !chmod 600 /root/.ssh/id_rsa
# !chmod 644 /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !ssh -T git@github.com

# %%
# Carrega os dados do Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/wrseg-2020
# Limpa as saídas do terminal
output.clear()

# %%
# Comandos git para manipulação do repositório local e via GitHub

# Configurações locais
# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"
# !rm /content/drive/MyDrive/wrseg-2020/.git/index.lock
# %cd /content/drive/MyDrive/wrseg-2020/

# Remove possíveis checkpoints antigas
# !rm -R /content/drive/MyDrive/wrseg-2020/checkpoints/* > /dev/null 

# Exibe o status do repositório local
#!git status

# %ls -alh

# Executa stash (se necessário), update, add, commit e push/pull para as alterações
#!git stash
# !git add .
# !git commit -m 'git_wrseg-2020.ipynb editado'
# !git push origin main
# Out:
# rm: cannot remove '/content/drive/MyDrive/wrseg-2020/.git/index.lock': No such file or directory
# /content/drive/MyDrive/wrseg-2020
# rm: cannot remove '/content/drive/MyDrive/wrseg-2020/checkpoints/*': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# ...
# Everything up-to-date
